# %% [markdown]
# # Gráficos dos resultados

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
os.chdir("SolarSystem_mvs-001/")

# %%
cabecalho = ["t","a","e","inc","capom","omega","capm","peri","apo","obar"]

# %%
mercury = pd.read_fwf("mercury.out", names = cabecalho)
venus = pd.read_fwf("venus.out", names = cabecalho)
earth = pd.read_fwf("earth.out", names = cabecalho)
mars = pd.read_fwf("mars.out", names = cabecalho)
jupiter = pd.read_fwf("jupiter.out", names = cabecalho)
saturn = pd.read_fwf("saturn.out", names = cabecalho)
uranus = pd.read_fwf("uranus.out", names = cabecalho)
neptune = pd.read_fwf("neptune.out", names = cabecalho)

time = jupiter.t

# %% [markdown]
# ## Excentricidade Gigantes

# %%
len(jupiter)
# Out:
# 2801

# %%
jupiter
# Out:
#                  t         a         e     inc     capom     omega      capm  \
# 0     0.000000e+00  5.204267  0.048775  1.3046  100.4917  275.0662   18.7767
# 1     5.000000e+03  5.201701  0.055849  1.2933  110.3386  276.2062  192.6111
# 2     1.000000e+04  5.202598  0.059643  1.4431  117.4961  282.7814    4.0960
# 3     1.500000e+04  5.201949  0.059582  1.6654  118.3452  295.5972  175.0321
# 4     2.000001e+04  5.203543  0.056938  1.8668  114.6615  312.5160  346.6409
# 5     2.500001e+04  5.201751  0.050285  1.9841  108.8399  331.3508  159.1609
# 6     3.000001e+04  5.203027  0.041389  1.9825  102.1426  345.5435  336.7387
# 7     3.500001e+04  5.202446  0.032138  1.8676   96.1094  354.4213  159.3113
# 8     4.000001e+04  5.201558  0.027650  1.6684   92.6777  345.6032  358.5086
# 9     4.500000e+04  5.203717  0.032821  1.4435   93.4605  335.5379  193.5289
# 10    5.000000e+04  5.202219  0.041155  1.2892  100.2134  330.4470   17.1862
# ...

# %%
plt.figure(figsize = (14, 6))
plt.plot(time, jupiter.e, label = "jupiter")
plt.plot(time, saturn.e, label = "saturn")
plt.plot(time, uranus.e, label = "uranus")
plt.plot(time, neptune.e, label = "neptune")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize = (14, 6))
plt.plot(time, jupiter.e, label = "jupiter")
plt.plot(time, saturn.e, label = "saturn")
plt.plot(time, uranus.e, label = "uranus")
plt.plot(time, neptune.e, label = "neptune")
plt.xlim(0,0.1e7)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Excentricidade dos internos

# %%
plt.figure(figsize = (14, 6))
plt.plot(time, mercury.e, label = "mercury")
plt.plot(time, venus.e, label = "venus")
plt.plot(time, earth.e, label = "earth")
plt.plot(time, mars.e, label = "mars")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize = (14, 6))
plt.plot(time, mercury.e, label = "mercury")
plt.plot(time, venus.e, label = "venus")
plt.plot(time, earth.e, label = "earth")
plt.plot(time, mars.e, label = "mars")
plt.xlim(0,0.3e7)
plt.legend()
plt.grid()
plt.show()

# %%
os.chdir("../")
